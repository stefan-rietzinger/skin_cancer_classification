# %%
import sys,os
import torch
import pandas as pd
from torchvision.io import read_image
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset_path = os.path.join(os.getcwd(),"..","data")
print(dataset_path)
folders_list = [folder for folder in os.listdir(dataset_path)]

for i,folders in enumerate(folders_list):
    print(f"{i} : {folders}")
# Out:
# /home/amstefansten/test/pytorch/skin_cancer/../data
# 0 : hmnist_8_8_RGB.csv
# 1 : hmnist_28_28_RGB.csv
# 2 : hmnist_8_8_L.csv
# 3 : HAM10000_metadata.csv
# 4 : ham10000_images_part_1
# 5 : hmnist_28_28_L.csv
# 6 : ham10000_images_part_2

# %%
metadata = pd.read_csv(os.path.join(dataset_path, folders_list[3]))

metadata.dx.unique()
# Out:
# array(['bkl', 'nv', 'df', 'mel', 'vasc', 'bcc', 'akiec'], dtype=object)

# %%
idx = 0 
image_name = f"{metadata.iloc[0].image_id}.jpg"

# if os.path.exists(os.path.join(dataset_path,"ham10000_images_part_1",image_name)):
#     print(os.path.join(dataset_path,"ham10000_images_part_1",image_name))
# elif os.path.exists(os.path.join(dataset_path,"ham10000_images_part_2",image_name)):
#     print(os.path.join(dataset_path,"ham10000_images_part_2",image_name))
# else:
#     raise Exception("FILE DOES NOT EXIST!")

image_directories = ["ham10000_images_part_1", "ham10000_images_part_2"]

for directory in image_directories:
    file_path = os.path.join(dataset_path, directory, image_name)
    if os.path.exists(file_path):
        image_directory = file_path
        break
else:
    raise Exception("FILE DOES NOT EXIST!")

print(file_path)
# Out:
# /home/amstefansten/test/pytorch/skin_cancer/../data/ham10000_images_part_1/ISIC_0027419.jpg

# %%
dx = metadata["dx"]
dx_dict = {IMAGE_ID : DX_ID for IMAGE_ID,DX_ID in zip(metadata["image_id"],dx)}

dx_dict
# Out:
# {'ISIC_0027419': 'bkl',
#  'ISIC_0025030': 'bkl',
#  'ISIC_0026769': 'bkl',
#  'ISIC_0025661': 'bkl',
#  'ISIC_0031633': 'bkl',
#  'ISIC_0027850': 'bkl',
#  'ISIC_0029176': 'bkl',
#  'ISIC_0029068': 'bkl',
#  'ISIC_0025837': 'bkl',
#  'ISIC_0025209': 'bkl',
#  'ISIC_0025276': 'bkl',
#  'ISIC_0029396': 'bkl',
#  'ISIC_0025984': 'bkl',
#  'ISIC_0025767': 'bkl',
#  'ISIC_0032417': 'bkl',
#  'ISIC_0031326': 'bkl',
#  'ISIC_0025915': 'bkl',
#  'ISIC_0031029': 'bkl',
#  'ISIC_0029836': 'bkl',
#  'ISIC_0032129': 'bkl',
#  'ISIC_0032343': 'bkl',
#  'ISIC_0025033': 'bkl',
#  'ISIC_0027310': 'bkl',
#  'ISIC_0032128': 'bkl',
#  'ISIC_0025937': 'bkl',
#  'ISIC_0027828': 'bkl',
#  'ISIC_0029291': 'bkl',
#  'ISIC_0030698': 'bkl',
#  'ISIC_0025567': 'bkl',
#  'ISIC_0031753': 'bkl',
#  'ISIC_0026835': 'bkl',
#  'ISIC_0031159': 'bkl',
#  'ISIC_0031017': 'bkl',
#  'ISIC_0024981': 'bkl',
#  'ISIC_0027815': 'bkl',
#  'ISIC_0024324': 'bkl',
#  'ISIC_0029559': 'bkl',
#  'ISIC_0030661': 'bkl',
# ...

# %%
image_path = os.path.join(dataset_path, folders_list[4])
images = [image_paths for image_paths in os.listdir(image_path)]

image_1_path = os.path.join(image_path,images[3])
image = read_image(image_1_path)

image
# Out:
# tensor([[[ 91,  95, 102,  ..., 168, 164, 162],
#          [ 94,  96, 105,  ..., 172, 164, 163],
#          [ 93,  99, 104,  ..., 174, 167, 167],
#          ...,
#          [203, 205, 206,  ..., 239, 240, 240],
#          [203, 201, 205,  ..., 239, 239, 239],
#          [204, 206, 206,  ..., 237, 237, 237]],
#
#         [[ 55,  60,  68,  ..., 120, 117, 117],
#          [ 59,  60,  66,  ..., 124, 121, 123],
#          [ 63,  65,  65,  ..., 127, 125, 131],
#          ...,
#          [153, 155, 151,  ..., 203, 204, 204],
#          [153, 149, 148,  ..., 203, 203, 203],
#          [154, 151, 151,  ..., 202, 202, 202]],
#
#         [[ 59,  64,  69,  ..., 134, 135, 138],
#          [ 63,  62,  69,  ..., 138, 141, 150],
#          [ 63,  66,  66,  ..., 145, 149, 157],
#          ...,
#          [154, 156, 154,  ..., 207, 208, 208],
#          [156, 153, 154,  ..., 207, 207, 207],
#          [157, 156, 156,  ..., 206, 206, 206]]], dtype=torch.uint8)

# %%
import numpy as np

A = []

def add(A):
    A.append(1)
    

add(A)

A
# Out:
# [1]

# %%
image_np = image.numpy()
image_np = np.transpose(image_np, (1,2,0))
plt.imshow(image_np)

# plt.imshow(image[0])
